# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh15698/Text_Prepro_Word_Embedding/blob/main/Text_Representation_Word_Embeddings_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Word2Vec

# %%
# https://drive.google.com/file/d/1lbtAwzE7l0otXYFDtGUKKWzI83bD5D5H/view?usp=drive_link

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
# !pip install --upgrade gensim --user

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
with open('/content/test.txt','r') as textfile:
  lines = textfile.readlines()
  raw_sent = sent_tokenize(str(lines))

# %%
raw_sent
# Out:
# ['[\'A Game Of Thrones Book One of A Song of Ice and Fire By George R. R. Martin PROLOGUE "We should start back," Gared urged as the woods began to grow dark around them.',
#  '"The wildlings are dead."',
#  '"Do the dead frighten you?"',
#  'Ser Waymar Royce asked with just the hint of a smile.',
#  'Gared did not rise to the bait.',
#  'He was an old man, past fifty, and he had seen the lordlings come and go.',
#  '"Dead is dead," he said.',
#  '"We have no business with the dead."',
#  '"Are they dead?"',
#  'Royce asked softly.',
#  '"What proof have we?"',
#  '"Will saw them," Gared said.',
#  '"If he says they are dead, that\\\'s proof enough for me."',
#  'Will had known they would drag him into the quarrel sooner or later.',
#  'He wished it had been later rather than sooner.',
#  '"My mother told me that dead men sing no songs," he put in.',
#  '"My wet nurse said the same thing, Will," Royce replied.',
#  '"Never believe anything you hear at a woman\\\'s tit.',
# ...

# %%
story = []
for sent in raw_sent:
  story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
len(story)
# Out:
# 8600

# %%
len(story)
# Out:
# 8602

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
story[0]
# Out:
# ['game',
#  'of',
#  'thrones',
#  'book',
#  'one',
#  'of',
#  'song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'by',
#  'george',
#  'martin',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them']

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (322659, 447775)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('still', 0.9991177320480347),
#  ('illyrio', 0.9990025162696838),
#  ('two', 0.9990000128746033),
#  ('three', 0.9989996552467346),
#  ('while', 0.9989977478981018),
#  ('an', 0.9989957213401794),
#  ('man', 0.9989815950393677),
#  ('other', 0.9989797472953796),
#  ('robb', 0.9989762306213379),
#  ('keep', 0.9989668726921082)]

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.99972105

# %%
model.wv['deep'].shape
# Out:
# (100,)

# %%
vec = model.wv.get_normed_vectors()

# %%
vec
# Out:
# array([[-0.12754397,  0.04952863,  0.0923628 , ..., -0.08613262,
#          0.07424022,  0.01438015],
#        [-0.12421791,  0.04668611,  0.08876292, ..., -0.08416584,
#          0.07084816,  0.005546  ],
#        [-0.08753459,  0.03115249,  0.07384279, ..., -0.08186632,
#          0.07300862, -0.02637934],
#        ...,
#        [-0.07427455,  0.10106399,  0.1040277 , ..., -0.10333119,
#          0.07375291,  0.01993317],
#        [-0.08343415,  0.06231723,  0.05244735, ..., -0.10698561,
#          0.05699311, -0.03404118],
#        [-0.00945447,  0.10254836, -0.00596046, ..., -0.06745199,
#          0.083828  , -0.03365115]], dtype=float32)

# %%
model.wv.get_normed_vectors().shape
# Out:
# (3840, 100)

# %%
y = model.wv.index_to_key

# %%
len(y)
# Out:
# 3840

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'he',
#  'of',
#  'his',
#  'was',
#  'her',
#  'it',
#  'in',
#  'you',
#  'had',
#  'she',
#  'that',
#  'him',
#  'with',
#  'as',
#  'said',
#  'not',
#  'at',
#  'for',
#  'on',
#  'is',
#  'they',
#  'but',
#  'from',
#  'no',
#  'were',
#  'have',
#  'my',
#  'jon',
#  'all',
#  'be',
#  'would',
#  'them',
#  'will',
#  'there',
#  'ned',
#  'bran',
#  'your',
#  'when',
#  'lord',
#  'so',
#  'are',
#  'up',
#  'me',
#  'could',
#  'man',
#  'what',
#  'king',
#  'one',
#  'if',
#  'out',
#  'this',
#  'arya',
#  'like',
#  'been',
#  'eyes',
#  'back',
#  'their',
#  'did',
#  'looked',
#  'ser',
#  'tyrion',
#  'hand',
#  'we',
#  'then',
#  'do',
#  'than',
#  'now',
#  'down',
#  'never',
#  'page',
#  'by',
#  'see',
#  'told',
#  'boy',
#  'father',
#  'here',
#  'only',
#  'sansa',
#  'brother',
#  'an',
#  'catelyn',
#  'robb',
#  'men',
#  'or',
#  'into',
#  'robert',
#  'old',
#  'over',
#  'even',
#  'face',
#  'long',
#  'more',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X
# Out:
# array([[-0.01675598,  0.19499919,  0.01000707],
#        [-0.02607192,  0.16161592,  0.0021562 ],
#        [-0.0521373 , -0.01867344, -0.0030181 ],
#        ...,
#        [ 0.028137  , -0.03106419,  0.05753305],
#        [-0.02441766,  0.06957541,  0.0268377 ],
#        [ 0.04797138, -0.09979656, -0.06907838]], dtype=float32)

# %%
X.shape
# Out:
# (3840, 3)

# %%
import plotly.express as px
fig = px.scatter_3d(X[200:300],x=0,y=1,z=2, color=y[200:300])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
